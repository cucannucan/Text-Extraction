# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/cucannucan/opt/anaconda3/lib/python3.8/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.17.0 in /Users/cucannucan/opt/anaconda3/lib/python3.8/site-packages (from opencv-python) (1.24.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !brew install tesseract
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Auto-updated Homebrew!
# Updated 3 taps (homebrew/services, homebrew/core and homebrew/cask).
# ==> New Formulae
# ansible-builder            libspelling@0.2            tex-fmt
# hawkeye                    sf                         wasi-libc
# kubetail                   sleek                      zsh-system-clipboard
# lbfgspp                    termscp
# ==> New Casks
# adlock                     font-mynaui-icons          singlebox
# follow                     huly                       unraid-usb-creator-next
# follow@nightly             lets                       webkinz
# font-doto                  mailbird
# font-faculty-glyphic       morisawa-desktop-manager
#
# You have 9 outdated formulae and 1 outdated cask installed.
#
# Warning: tesseract 5.4.1_1 is already installed and up-to-date.
# To reinstall 5.4.1_1, run:
#   brew reinstall tesseract

# %%
# %pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /Users/cucannucan/opt/anaconda3/lib/python3.8/site-packages (0.3.13)
# Requirement already satisfied: Pillow>=8.0.0 in /Users/cucannucan/opt/anaconda3/lib/python3.8/site-packages (from pytesseract) (9.3.0)
# Requirement already satisfied: packaging>=21.3 in /Users/cucannucan/opt/anaconda3/lib/python3.8/site-packages (from pytesseract) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pytesseract
from matplotlib import pyplot as plt

# %%
# Load the image from file
image = cv2.imread('WhatsApp.png') 

# Display the original image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.show()

# %%
# Convert the image to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding (optional, but useful for clean text)
_, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)

# Display the preprocessed image
plt.imshow(thresh, cmap='gray')
plt.title('Preprocessed Image')
plt.show()

# %%
# Extract text from the preprocessed image
extracted_text = pytesseract.image_to_string(thresh)

# Print the extracted text
print("Extracted Text:")
print(extracted_text)
# Out:
# Extracted Text:
# Sy m 14:05
#
# Can we have a very faked conversation
# about it haha 14-01
#
# About what
# The blue ticks 54.9;
# Oh hahaha sure
#
# Hey look the whatsapp arrows are blue
# now! 14:02
#
# Wait when did this happen? What does
# that mean
#
# Is this that whole thing about delivery
# statuses changing? 14:03
#
# The blue means it's actually read, right?
# 14:03
#
# As opposed to Just Delivered? 44.94
#
# ABOUT TIME
#
# © Oo &
